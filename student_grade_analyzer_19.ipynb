# %% [markdown]
# <a href="https://colab.research.google.com/github/kartikthakur99/Davis_Training/blob/main/student_grade_analyzer_19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def calculate_grade(marks):
    if marks >= 90 and marks <= 100:
        return "A"
    elif marks >= 75 and marks <= 89:
        return "B"
    elif marks >= 50 and marks <= 74:
        return "C"
    elif marks >= 0 and marks < 50:
        return "Fail"
    else:
        return "Invalid Marks"


# Processing marks of 5 students
for i in range(1, 6):
    marks = int(input(f"Enter marks of student {i}: "))
    grade = calculate_grade(marks)
    print(f"Student {i} Grade: {grade}")
# Out:
# Enter marks of student 1: 95
# Student 1 Grade: A
# Enter marks of student 2: 80
# Student 2 Grade: B
# Enter marks of student 3: 65
# Student 3 Grade: C
# Enter marks of student 4: 40
# Student 4 Grade: Fail
# Enter marks of student 5: 110
# Student 5 Grade: Invalid Marks
