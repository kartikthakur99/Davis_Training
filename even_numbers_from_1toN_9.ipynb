# %% [markdown]
# <a href="https://colab.research.google.com/github/kartikthakur99/Davis_Training/blob/main/Untitledeven.numbers.from.1toN9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input("Enter N: "))

print("Even numbers:")
for i in range(1, n + 1):
    if i % 2 == 0:
        print(i, end=" ")
# Out:
# Enter N: 10
# Even numbers:
# 2 4 6 8 10
